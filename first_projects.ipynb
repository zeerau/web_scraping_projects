# %%
from bs4 import BeautifulSoup
import requests

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Data+Scientist&txtLocation=').text
soup = BeautifulSoup(html_text,'lxml')
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
for job in jobs :
    published_date = job.find('span', class_ = 'sim-posted').span.text
    if 'few' in published_date :
        company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ', '')
        skills = job.find('span', class_='srp-skills').text.replace(' ', '')
        

        print(f'''
        Company Name: {company_name}
        Required Skills:{skills}
        ''')
        print('')
# Out:
#         Company Name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#         Required Skills:
# DataScientist,startupenvironment,algorithms
#
#
#
#
#
#         Company Name:
# ArmacoChemicalProcessesSystemsPvtLtd
#
#
#         Required Skills:
#
# businesssystem,infrastructure,datascientist
#
#
#
#
#         Company Name:
# RedLotus
#
#
#         Required Skills:
# datascientist,statisticalmodeling,datavisualization
#
#
#
#
#
#         Company Name:
# DatagridSolutions
#
#
#         Required Skills:
# dataanalysis,linearregression,ensemble,tableau,datascience,datascientist,datavisualization
#
#
#
#
#
#         Company Name:
# ArmacoChemicalProcessesSystemsPvtLtd
#
#
#         Required Skills:
#
# bi,sql,database,datascience,datascientist,datavisualization,dataanalytics,tableau,qliksense,infrastructure
#
#
#
#
#
#         Company Name:
# WALMARTINDIA
#
#
#         Required Skills:
#
# c,bi,datascience,usecases,datascientist,datavisualization,clusteranalysis,dataanalysis,bigdataanalytics,tableau,statisticalanalysis
#
#
#
#
#
#         Company Name:
# WALMARTINDIA
#
#
#         Required Skills:
#
# sql,datascience,usecases,datascientist,datavisualization,clusteranalysis,dataanalysis,bigdataanalytics,predictivemodeling,statisticalanalysis
#
#
#
#
#
#         Company Name:
# APPLYCUPHIRINGSOLUTIONSLLP
#
#
#         Required Skills:
#
# visualization,sas,regressionanalysis,businessanalytics,dashboards,sql,tableau,java,datascience,datascientist,unix/linux
#
#
#
#
#
#         Company Name:
# WALMARTINDIA
#
#
#         Required Skills:
#
# visualization,sql,dataextraction,datascience,usecases,datascientist,clusteranalysis,dataanalysis,sas,bigdataanalytics,statisticalanalysis
#
#
#
#
#
#         Company Name:
# EfftronicsSystemsPvtLtd
#
#
#         Required Skills:
#
# c,dataanalysis,businessrequirements,datamining,java,predictivemodeling,datascientist,statisticalanalysis,designthinking,predictiveanalysis
#
#
#
#
#
#         Company Name:
# BizVizTechnologies
#
#
#         Required Skills:
# datamining,sql,datascientist,predictiveanalysis,advancedanalytics,dataanalysis,sas,author,predictiveanalytics,algorithmdevelopment,statisticalanalysis
#
#
#
#
#
#         Company Name:
# axmiyanhrsolutionsprivatelimited
#
#
#         Required Skills:
#
# timeseriesanalysis,linearregression,datascience,datascientist,logisticregression,imageprocessing,advancedanalytics,factoranalysis
#
#
#
#
#
#         Company Name:
# WALMARTINDIA
#
#
#         Required Skills:
#
# bi,sql,datascience,usecases,datascientist,clusteranalysis,dataanalysis,bigdataanalytics,msaccess,alteryx,tableau,statisticalanalysis
#
#
#
#
#
#         Company Name:
# stringbiopvt.ltd
#
#
#         Required Skills:
#
# algorithms,c,datamining,sql,python
#
#
#
#
#
#         Company Name:
# TandAHRSolutions
#
#
#         Required Skills:
#
# hive,algorithms,datamining,pig,datastructures,hadoop,bigdata,python,sas,oozie,machinelearning
#
#
#
#
#
#         Company Name:
# BrainToSoulConsulting
#
#
#         Required Skills:
#
# hive,datamining,sql,nosql,mongodb
